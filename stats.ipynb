# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels = ["Country", "Year", "Sex", "Age", "Suicide Numbers", "Population" ]
df = pd.read_csv('death.csv', names=labels, header=0)
df.head()
# Out:
#    Country  Year     Sex          Age  Suicide Numbers  Population
# 0  Albania  1985  female  15-24 years              NaN    277900.0
# 1  Albania  1985  female  25-34 years              NaN    246800.0
# 2  Albania  1985  female  35-54 years              NaN    267500.0
# 3  Albania  1985  female   5-14 years              NaN    298300.0
# 4  Albania  1985  female  55-74 years              NaN    138700.0

# %%
df.isnull().sum()
# Out:
# Country            0
# Year               0
# Sex                0
# Age                0
# Suicide Numbers    0
# Population         0
# dtype: int64

# %%
#Remove all NAN from dataset
df['Suicide Numbers'].fillna(0, inplace=True)
df['Population'].fillna(0, inplace=True)

# %%
df.head()
# Out:
#    Country  Year     Sex          Age  Suicide Numbers  Population
# 0  Albania  1985  female  15-24 years              0.0    277900.0
# 1  Albania  1985  female  25-34 years              0.0    246800.0
# 2  Albania  1985  female  35-54 years              0.0    267500.0
# 3  Albania  1985  female   5-14 years              0.0    298300.0
# 4  Albania  1985  female  55-74 years              0.0    138700.0

# %%
df
# Out:
#                     Country  Year     Sex          Age  Suicide Numbers  \
# 0                   Albania  1985  female  15-24 years              0.0
# 1                   Albania  1985  female  25-34 years              0.0
# 2                   Albania  1985  female  35-54 years              0.0
# 3                   Albania  1985  female   5-14 years              0.0
# 4                   Albania  1985  female  55-74 years              0.0
# 5                   Albania  1985  female    75+ years              0.0
# 6                   Albania  1985    male  15-24 years              0.0
# 7                   Albania  1985    male  25-34 years              0.0
# 8                   Albania  1985    male  35-54 years              0.0
# 9                   Albania  1985    male   5-14 years              0.0
# 10                  Albania  1985    male  55-74 years              0.0
# 11                  Albania  1985    male    75+ years              0.0
# ...

# %%
df.groupby('Country').sum()
# Out:
#                                       Year  Suicide Numbers    Population
# Country
# Albania                             744000           1970.0  8.699271e+07
# Anguilla                            695832              2.0  0.000000e+00
# Antigua and Barbuda                 671628             11.0  2.054919e+06
# Argentina                           886668          93862.0  1.190238e+09
# Armenia                             839544           2422.0  1.067432e+08
# Aruba                               481092            120.0  1.762045e+06
# Australia                           886668          80279.0  6.443903e+08
# Austria                             910860          60179.0  2.873090e+08
# Azerbaijan                          598176           3366.0  1.664882e+08
# Bahamas                             695136            107.0  7.715548e+06
# Bahrain                             504708            463.0  1.675393e+07
# Barbados                            742440            205.0  7.590791e+06
# ...

# %%
df["Suicide Numbers"].mean()
# Out:
# 183.35286458333334

# %%
df["Suicide Numbers"].min()
# Out:
# 0.0

# %%
df['Country'].head(200)
# Out:
# 0      Albania
# 1      Albania
# 2      Albania
# 3      Albania
# 4      Albania
# 5      Albania
# 6      Albania
# 7      Albania
# 8      Albania
# 9      Albania
# 10     Albania
# 11     Albania
# 12     Albania
# 13     Albania
# 14     Albania
# 15     Albania
# 16     Albania
# 17     Albania
# 18     Albania
# 19     Albania
# 20     Albania
# 21     Albania
# 22     Albania
# 23     Albania
# 24     Albania
# 25     Albania
# 26     Albania
# 27     Albania
# 28     Albania
# 29     Albania
#         ...
# 170    Albania
# 171    Albania
# 172    Albania
# 173    Albania
# 174    Albania
# 175    Albania
# 176    Albania
# 177    Albania
# 178    Albania
# 179    Albania
# 180    Albania
# 181    Albania
# 182    Albania
# 183    Albania
# 184    Albania
# 185    Albania
# 186    Albania
# 187    Albania
# 188    Albania
# 189    Albania
# 190    Albania
# 191    Albania
# 192    Albania
# 193    Albania
# 194    Albania
# 195    Albania
# 196    Albania
# 197    Albania
# ...

# %%
death_filter = df['Suicide Numbers'] > 19000
death_filter
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 43746    False
# 43747    False
# 43748    False
# 43749    False
# 43750    False
# 43751    False
# 43752    False
# 43753    False
# 43754    False
# 43755    False
# 43756    False
# 43757    False
# 43758    False
# 43759    False
# 43760    False
# 43761    False
# 43762    False
# 43763    False
# 43764    False
# 43765    False
# 43766    False
# 43767    False
# 43768    False
# 43769    False
# 43770    False
# 43771    False
# 43772    False
# ...

# %%
filtered_df = df[death_filter]
filtered_df.head()
# Out:
#                   Country  Year   Sex          Age  Suicide Numbers  \
# 33116  Russian Federation  1993  male  35-54 years          20256.0
# 33128  Russian Federation  1994  male  35-54 years          22338.0
# 33140  Russian Federation  1995  male  35-54 years          21706.0
# 33152  Russian Federation  1996  male  35-54 years          20562.0
# 33188  Russian Federation  1999  male  35-54 years          20705.0
#
#        Population
# 33116  18908000.0
# 33128  19044200.0
# 33140  19249600.0
# 33152  19507100.0
# 33188  21016400.0

# %%
sex_filter = (df["Suicide Numbers"] > 22000) & (df["Sex"] == "male")
filtered_df = df[sex_filter]
filtered_df.head()
# Out:
#                   Country  Year   Sex          Age  Suicide Numbers  \
# 33128  Russian Federation  1994  male  35-54 years          22338.0
#
#        Population
# 33128  19044200.0

# %%
sex_filter = (df["Suicide Numbers"] > 10) & (df["Sex"] == "male")
filtered_df = df[sex_filter]
filtered_df.head()
# Out:
#     Country  Year   Sex          Age  Suicide Numbers  Population
# 30  Albania  1987  male  15-24 years             21.0    312900.0
# 32  Albania  1987  male  35-54 years             16.0    308000.0
# 42  Albania  1988  male  15-24 years             17.0    319200.0
# 44  Albania  1988  male  35-54 years             14.0    314100.0
# 54  Albania  1989  male  15-24 years             12.0    323500.0

# %%
sex_filter = (df["Suicide Numbers"] > 4050) & (df["Sex"] == "female")
filtered_df = df[sex_filter]
filtered_df.head()
# Out:
#                         Country  Year     Sex          Age  Suicide Numbers  \
# 42350  United States of America  2015  female  35-54 years           4053.0
#
#        Population
# 42350  41531809.0

# %%
year_filter = (df["Year"] > 1985) & (df["Suicide Numbers"] >= 8000 )
filtered_df = df[year_filter]
filtered_df.head()
# Out:
#       Country  Year   Sex          Age  Suicide Numbers  Population
# 20984   Japan  1998  male  35-54 years           8384.0  17557000.0
# 20996   Japan  1999  male  35-54 years           8340.0  17403000.0
# 21008   Japan  2000  male  35-54 years           8023.0  17540437.0
# 21032   Japan  2002  male  35-54 years           8202.0  17249000.0
# 21044   Japan  2003  male  35-54 years           8948.0  16966000.0

# %%
colors = ['red', 'blue']
color_means = df.groupby('Year')['Suicide Numbers'].mean()
color_means.plot(kind='bar', title="Average, type(color)", color=colors)
plt.xlabel('Colors', fontsize=20)
plt.ylabel('Colors', fontsize=20)
plt.grid()
plt.show()

# %%
colors = ['red', 'blue']
color_means = df.groupby('Sex')['Suicide Numbers'].mean()
color_means.plot(kind='bar', title=Average, type(color)", color=colors)
plt.xlabel('Colors', fontsize=20)
plt.ylabel('Colors', fontsize=20)
plt.grid()
plt.show()
# Out:
#   File "<ipython-input-118-e50beb0415e7>", line 3
#     color_means.plot(kind='bar', title=Average, type(color)", color=colors)
#                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
df["Sex"].value_counts(["Suicide Numbers"])
# Out:
# female    0.5
# male      0.5
# Name: Sex, dtype: float64

# %%
grouped["Suicide Numbers"].agg(np.mean)
# Out:
# Suicide Numbers
# 0.0            0.0
# 1.0            1.0
# 2.0            2.0
# 3.0            3.0
# 4.0            4.0
# 5.0            5.0
# 6.0            6.0
# 7.0            7.0
# 8.0            8.0
# 9.0            9.0
# 10.0          10.0
# 11.0          11.0
# 12.0          12.0
# 13.0          13.0
# 14.0          14.0
# 15.0          15.0
# 16.0          16.0
# 17.0          17.0
# 18.0          18.0
# 19.0          19.0
# 20.0          20.0
# 21.0          21.0
# 22.0          22.0
# 23.0          23.0
# 24.0          24.0
# 25.0          25.0
# 26.0          26.0
# 27.0          27.0
# 28.0          28.0
# 29.0          29.0
#             ...
# 11613.0    11613.0
# 11634.0    11634.0
# 11681.0    11681.0
# 11721.0    11721.0
# 11763.0    11763.0
# 11767.0    11767.0
# 11848.0    11848.0
# 12030.0    12030.0
# 12517.0    12517.0
# 12746.0    12746.0
# 13065.0    13065.0
# 14020.0    14020.0
# 14891.0    14891.0
# 15824.0    15824.0
# 15843.0    15843.0
# ...

# %%
grouped["Year"].agg(np.mean)
# Out:
# Suicide Numbers
# 0.0        1997.283081
# 1.0        1999.862663
# 2.0        1999.693986
# 3.0        1999.650039
# 4.0        1999.122070
# 5.0        1999.991422
# 6.0        1999.094477
# 7.0        1999.314785
# 8.0        1999.690909
# 9.0        1998.896484
# 10.0       1999.193473
# 11.0       1999.086331
# 12.0       1999.171831
# 13.0       1999.014837
# 14.0       1998.551724
# 15.0       1998.456193
# 16.0       1997.651515
# 17.0       1999.513793
# 18.0       1999.586207
# 19.0       1998.206897
# 20.0       1999.500000
# 21.0       1998.121771
# 22.0       1998.506173
# 23.0       1998.942387
# 24.0       1998.000000
# 25.0       1997.163462
# 26.0       1997.953608
# 27.0       1998.313433
# 28.0       1997.635417
# 29.0       1998.136585
#               ...
# 11613.0    2009.000000
# 11634.0    2015.000000
# 11681.0    2011.000000
# 11721.0    2009.000000
# 11763.0    2012.000000
# 11767.0    2010.000000
# 11848.0    2008.000000
# 12030.0    1989.000000
# ...

# %%
year_filter = (df["Year"] > 1985) & (df["Suicide Numbers"].avg)
filtered_df = df[year_filter]
grouped = data.groupby(["What type of cranberry saucedo you typically have?", "What is typically the main dish at your Thanksgiving dinner?"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-131bb4b4c805> in <module>
# ----> 1 year_filter = (df["Year"] > 1985) & (df["Suicide Numbers"].avg)
#       2 filtered_df = df[year_filter]
#       3 filtered_df.head()
#
# /anaconda3/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'avg'
